# %%
# !rm -rf EmbryoQualityPrediction  # remove the current D folder if it’s not a real repo
# !git clone https://github.com/reachtokarthik/EmbryoQualityPrediction.git
# !cd EmbryoQualityPrediction && git log -1
# Out:
# Cloning into 'EmbryoQualityPrediction'...
# remote: Enumerating objects: 52437, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 52437 (delta 67), reused 55 (delta 30), pack-reused 52337 (from 1)
# Receiving objects: 100% (52437/52437), 965.90 MiB | 17.39 MiB/s, done.
# Resolving deltas: 100% (231/231), done.
# commit 4b469910ce04d55883508b55e2d2bde16ebec22e (HEAD -> main, origin/main, origin/HEAD)
# Author: reachtokarthik <reachtokarthikeyan@outlook.com>
# Date:   Sat Apr 26 16:52:35 2025 +0530
#
#     Add initial report generator classes and workflow runner script

# %%
# !python /content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py --test

# %%
# !python /content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py
# Out:
# Streaming output truncated to the last 5000 lines.
# ✅ Copied Blastocyst_B (27).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (94).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (71).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (13).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (40).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (72).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (34).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (32).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (57).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (41).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (19).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (20).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B.jpeg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (18).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (45).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (97).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (86).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (68).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (92).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (28).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (11).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (103).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (48).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (58).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (50).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (26).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (44).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (15).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (21).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (48).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (21).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (17).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (31).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (50).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (34).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (9).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (18).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (76).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (47).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (15).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (8).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (27).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (37).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (79).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (46).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B.jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (19).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (23).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (65).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (14).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (20).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (64).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (84).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (38).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (22).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (83).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (73).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (49).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (101).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (25).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (90).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (9).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (82).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (91).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (106).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (100).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (55).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (59).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (10).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (61).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (32).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (38).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B.webp → blastocyst_grade_B
# ✅ Copied Blastocyst_B (33).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (42).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (43).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (45).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (104).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (22).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (16).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (51).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (54).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (39).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (51).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (30).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (49).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (35).png → blastocyst_grade_B
# ✅ Copied Blastocyst_B (44).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (53).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (16).jpg → blastocyst_grade_B
# ✅ Copied Blastocyst_B (54).png → blastocyst_grade_B
# ✅ Copied Blastocyst_A (22).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (143).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (43).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (110).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (139).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (129).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (84).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (28).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (49).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (128).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (140).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (124).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (39).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A.png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (133).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (40).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (47).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (73).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (52).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (86).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (44).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (40).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (114).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (137).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (50).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (113).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (119).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (46).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (98).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (142).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A.jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (38).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (28).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (92).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (64).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (106).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (29).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (127).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (54).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (93).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (36).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (78).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (102).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (135).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (120).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (38).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (108).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (56).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (126).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (91).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (144).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (62).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (138).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (43).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (109).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (32).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (41).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (130).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (122).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (33).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (69).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (29).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (50).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (90).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (35).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (74).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (94).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (99).jpg → blastocyst_grade_A
# ✅ Copied Blatocyst_A.jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (105).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (65).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (31).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (22).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (81).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (132).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (36).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (16).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (72).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (67).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (51).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (10).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (75).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (60).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (48).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (66).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (123).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (39).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (30).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (82).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (96).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (117).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (89).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (79).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (46).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (44).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (103).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (118).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (83).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (33).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (58).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (16).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (121).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (37).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (34).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (125).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (76).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (32).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (107).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (115).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (112).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (41).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (85).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (30).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (63).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (136).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (37).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (68).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (80).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (42).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (42).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (53).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (131).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (111).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (59).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (45).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (116).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (48).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (101).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (70).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (134).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (31).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (49).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (10).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (57).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (34).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (97).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (141).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (35).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (61).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (47).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (88).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (71).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (77).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (104).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (87).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (45).png → blastocyst_grade_A
# ✅ Copied Blastocyst_A (100).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (95).jpg → blastocyst_grade_A
# ✅ Copied Blastocyst_A (55).jpg → blastocyst_grade_A
# ✅ Copied image_359.jpg → error_images
# ✅ Copied image_228.jpg → error_images
# ✅ Copied image_158.jpg → error_images
# ✅ Copied image_433.jpg → error_images
# ✅ Copied image_449.jpg → error_images
# ✅ Copied image_322.jpg → error_images
# ✅ Copied image_466.jpg → error_images
# ✅ Copied image_109.jpg → error_images
# ✅ Copied image_258.jpg → error_images
# ✅ Copied image_120.jpg → error_images
# ✅ Copied image_32.jpg → error_images
# ✅ Copied image_112.jpg → error_images
# ✅ Copied image_458.jpg → error_images
# ✅ Copied image_234.jpg → error_images
# ✅ Copied image_176.jpg → error_images
# ✅ Copied image_253.jpg → error_images
# ✅ Copied image_72.jpg → error_images
# ✅ Copied image_470.jpg → error_images
# ✅ Copied image_331.jpg → error_images
# ✅ Copied Image_17.jpg → error_images
# ✅ Copied image_227.jpg → error_images
# ✅ Copied image_232.jpg → error_images
# ✅ Copied image_392.jpg → error_images
# ✅ Copied image_468.jpg → error_images
# ✅ Copied image_59.jpg → error_images
# ✅ Copied image_296.jpg → error_images
# ✅ Copied image_462.jpg → error_images
# ✅ Copied image_416.jpg → error_images
# ✅ Copied image_40.jpg → error_images
# ✅ Copied image_280.jpg → error_images
# ✅ Copied image_188.jpg → error_images
# ✅ Copied image_69.jpg → error_images
# ✅ Copied image_453.jpg → error_images
# ✅ Copied image_278.jpg → error_images
# ✅ Copied image_95.jpg → error_images
# ✅ Copied image_251.jpg → error_images
# ✅ Copied image_334.jpg → error_images
# ✅ Copied image_190.jpg → error_images
# ✅ Copied image_125.jpg → error_images
# ✅ Copied image_344.jpg → error_images
# ✅ Copied image_28.jpg → error_images
# ✅ Copied image_318.jpg → error_images
# ✅ Copied image_409.jpg → error_images
# ✅ Copied image_153.jpg → error_images
# ✅ Copied image_58.jpg → error_images
# ✅ Copied image_421.jpg → error_images
# ✅ Copied image_123.jpg → error_images
# ✅ Copied image_172.jpg → error_images
# ✅ Copied image_124.jpg → error_images
# ✅ Copied image_161.jpg → error_images
# ✅ Copied image_47.jpg → error_images
# ✅ Copied image_213.jpg → error_images
# ✅ Copied image_436.jpg → error_images
# ✅ Copied image_179.jpg → error_images
# ✅ Copied image_419.jpg → error_images
# ✅ Copied image_403.jpg → error_images
# ✅ Copied image_356.jpg → error_images
# ✅ Copied image_138.jpg → error_images
# ✅ Copied image_439.jpg → error_images
# ✅ Copied image_475.jpg → error_images
# ✅ Copied image_119.jpg → error_images
# ✅ Copied image_397.jpg → error_images
# ✅ Copied image_381.jpg → error_images
# ✅ Copied image_302.jpg → error_images
# ✅ Copied image_379.jpg → error_images
# ✅ Copied image_169.jpg → error_images
# ✅ Copied image_500.jpg → error_images
# ✅ Copied image_209.jpg → error_images
# ✅ Copied image_487.jpg → error_images
# ✅ Copied image_358.jpg → error_images
# ✅ Copied Image_14.jpg → error_images
# ✅ Copied image_184.jpg → error_images
# ✅ Copied image_301.jpg → error_images
# ✅ Copied image_174.jpg → error_images
# ✅ Copied image_499.jpg → error_images
# ✅ Copied image_100.jpg → error_images
# ✅ Copied image_30.jpg → error_images
# ✅ Copied Image_9.jpg → error_images
# ✅ Copied image_90.jpg → error_images
# ✅ Copied image_240.jpg → error_images
# ✅ Copied image_460.jpg → error_images
# ✅ Copied image_469.jpg → error_images
# ✅ Copied image_154.jpg → error_images
# ✅ Copied image_305.jpg → error_images
# ✅ Copied image_267.jpg → error_images
# ✅ Copied image_182.jpg → error_images
# ✅ Copied image_128.jpg → error_images
# ✅ Copied image_396.jpg → error_images
# ✅ Copied image_142.jpg → error_images
# ✅ Copied Image_13.jpg → error_images
# ✅ Copied Image_2.jpeg → error_images
# ✅ Copied image_206.jpg → error_images
# ✅ Copied image_448.jpg → error_images
# ✅ Copied image_435.jpg → error_images
# ✅ Copied image_498.jpg → error_images
# ✅ Copied image_147.jpg → error_images
# ✅ Copied image_121.jpg → error_images
# ✅ Copied image_44.jpg → error_images
# ✅ Copied image_284.jpg → error_images
# ✅ Copied image_271.jpg → error_images
# ✅ Copied image_92.jpg → error_images
# ✅ Copied image_131.jpg → error_images
# ✅ Copied image_399.jpg → error_images
# ✅ Copied image_45.jpg → error_images
# ✅ Copied image_265.jpg → error_images
# ✅ Copied image_86.jpg → error_images
# ✅ Copied image_239.jpg → error_images
# ✅ Copied image_286.jpg → error_images
# ✅ Copied image_345.jpg → error_images
# ✅ Copied image_335.jpg → error_images
# ✅ Copied image_257.jpg → error_images
# ✅ Copied image_310.jpg → error_images
# ✅ Copied image_285.jpg → error_images
# ✅ Copied image_349.jpg → error_images
# ✅ Copied image_70.jpg → error_images
# ✅ Copied image_199.jpg → error_images
# ✅ Copied image_479.jpg → error_images
# ✅ Copied image_492.jpg → error_images
# ✅ Copied image_224.jpg → error_images
# ✅ Copied image_420.jpg → error_images
# ✅ Copied image_215.jpg → error_images
# ✅ Copied image_33.jpg → error_images
# ✅ Copied Image_18.jpg → error_images
# ✅ Copied image_424.jpg → error_images
# ✅ Copied image_385.jpg → error_images
# ✅ Copied image_160.jpg → error_images
# ✅ Copied image_104.jpg → error_images
# ✅ Copied image_390.jpg → error_images
# ✅ Copied image_21.jpg → error_images
# ✅ Copied image_219.jpg → error_images
# ✅ Copied image_413.jpg → error_images
# ✅ Copied image_166.jpg → error_images
# ✅ Copied image_446.jpg → error_images
# ✅ Copied image_343.jpg → error_images
# ✅ Copied image_230.jpg → error_images
# ✅ Copied image_53.jpg → error_images
# ✅ Copied image_134.jpg → error_images
# ✅ Copied image_328.jpg → error_images
# ✅ Copied image_323.jpg → error_images
# ✅ Copied image_288.jpg → error_images
# ✅ Copied image_223.jpg → error_images
# ✅ Copied image_393.jpg → error_images
# ✅ Copied image_455.jpg → error_images
# ✅ Copied image_221.jpg → error_images
# ✅ Copied image_287.jpg → error_images
# ✅ Copied image_346.jpg → error_images
# ✅ Copied image_467.jpg → error_images
# ✅ Copied image_428.jpg → error_images
# ✅ Copied image_317.jpg → error_images
# ✅ Copied image_187.jpg → error_images
# ✅ Copied image_49.jpg → error_images
# ✅ Copied image_373.jpg → error_images
# ✅ Copied image_407.jpg → error_images
# ✅ Copied image_489.jpg → error_images
# ✅ Copied image_471.jpg → error_images
# ✅ Copied image_50.jpg → error_images
# ✅ Copied image_431.jpg → error_images
# ✅ Copied image_180.jpg → error_images
# ✅ Copied image_107.jpg → error_images
# ✅ Copied image_60.jpg → error_images
# ✅ Copied image_480.jpg → error_images
# ✅ Copied image_368.jpg → error_images
# ✅ Copied image_401.jpg → error_images
# ✅ Copied image_246.jpg → error_images
# ✅ Copied image_484.jpg → error_images
# ✅ Copied image_75.jpg → error_images
# ✅ Copied image_222.jpg → error_images
# ✅ Copied image_80.jpg → error_images
# ✅ Copied image_151.jpg → error_images
# ✅ Copied image_248.jpg → error_images
# ✅ Copied image_159.jpg → error_images
# ✅ Copied image_423.jpg → error_images
# ✅ Copied image_363.jpg → error_images
# ✅ Copied image_269.jpg → error_images
# ✅ Copied image_445.jpg → error_images
# ✅ Copied image_434.jpg → error_images
# ✅ Copied image_264.jpg → error_images
# ✅ Copied image_450.jpg → error_images
# ✅ Copied image_43.jpg → error_images
# ✅ Copied image_247.jpg → error_images
# ✅ Copied image_425.jpg → error_images
# ✅ Copied image_454.jpg → error_images
# ✅ Copied image_374.jpg → error_images
# ✅ Copied image_380.jpg → error_images
# ✅ Copied image_98.jpg → error_images
# ✅ Copied Image_15.jpg → error_images
# ✅ Copied Image_8.jpg → error_images
# ✅ Copied image_277.jpg → error_images
# ✅ Copied image_497.jpg → error_images
# ✅ Copied image_341.jpg → error_images
# ✅ Copied image_383.jpg → error_images
# ✅ Copied image_61.jpg → error_images
# ✅ Copied image_297.jpg → error_images
# ✅ Copied Image_20.webp → error_images
# ✅ Copied image_96.jpg → error_images
# ✅ Copied image_337.jpg → error_images
# ✅ Copied image_410.jpg → error_images
# ✅ Copied image_324.jpg → error_images
# ✅ Copied image_386.jpg → error_images
# ✅ Copied image_177.jpg → error_images
# ✅ Copied image_404.jpg → error_images
# ✅ Copied image_321.jpg → error_images
# ✅ Copied image_210.jpg → error_images
# ✅ Copied Image_4.jpg → error_images
# ✅ Copied image_236.jpg → error_images
# ✅ Copied image_99.jpg → error_images
# ✅ Copied image_22.jpg → error_images
# ✅ Copied image_429.jpg → error_images
# ✅ Copied Image_4.jpeg → error_images
# ✅ Copied image_220.jpg → error_images
# ✅ Copied image_208.jpg → error_images
# ✅ Copied image_488.jpg → error_images
# ✅ Copied image_387.jpg → error_images
# ✅ Copied image_340.jpg → error_images
# ✅ Copied image_476.jpg → error_images
# ✅ Copied image_360.jpg → error_images
# ✅ Copied image_432.jpg → error_images
# ✅ Copied image_418.jpg → error_images
# ✅ Copied image_122.jpg → error_images
# ✅ Copied image_126.jpg → error_images
# ✅ Copied image_275.jpg → error_images
# ✅ Copied image_55.jpg → error_images
# ✅ Copied image_366.jpg → error_images
# ✅ Copied image_279.jpg → error_images
# ✅ Copied image_139.jpg → error_images
# ✅ Copied image_474.jpg → error_images
# ✅ Copied image_372.jpg → error_images
# ✅ Copied image_244.jpg → error_images
# ✅ Copied image_362.jpg → error_images
# ✅ Copied Image_6.jpg → error_images
# ✅ Copied image_136.jpg → error_images
# ✅ Copied image_81.jpg → error_images
# ✅ Copied image_364.jpg → error_images
# ✅ Copied image_262.jpg → error_images
# ✅ Copied image_481.jpg → error_images
# ✅ Copied image_77.jpg → error_images
# ✅ Copied image_400.jpg → error_images
# ✅ Copied image_291.jpg → error_images
# ✅ Copied image_233.jpg → error_images
# ✅ Copied image_93.jpg → error_images
# ✅ Copied image_495.jpg → error_images
# ✅ Copied image_149.jpg → error_images
# ✅ Copied image_175.jpg → error_images
# ✅ Copied image_66.jpg → error_images
# ✅ Copied image_143.jpg → error_images
# ✅ Copied image_140.jpg → error_images
# ✅ Copied image_148.jpg → error_images
# ✅ Copied image_116.jpg → error_images
# ✅ Copied image_242.jpg → error_images
# ✅ Copied image_483.jpg → error_images
# ✅ Copied image_35.jpg → error_images
# ✅ Copied Image_19.jpg → error_images
# ✅ Copied image_313.jpg → error_images
# ✅ Copied image_382.jpg → error_images
# ✅ Copied image_357.jpg → error_images
# ✅ Copied image_46.jpg → error_images
# ✅ Copied image_459.jpg → error_images
# ✅ Copied image_214.jpg → error_images
# ✅ Copied Image_3.jpg → error_images
# ✅ Copied image_427.jpg → error_images
# ✅ Copied image_270.jpg → error_images
# ✅ Copied image_245.jpg → error_images
# ✅ Copied image_54.jpg → error_images
# ✅ Copied image_181.jpg → error_images
# ✅ Copied image_74.jpg → error_images
# ✅ Copied image_319.jpg → error_images
# ✅ Copied image_111.jpg → error_images
# ✅ Copied image_437.jpg → error_images
# ✅ Copied image_320.jpg → error_images
# ✅ Copied image_456.jpg → error_images
# ✅ Copied image_355.jpg → error_images
# ✅ Copied image_259.jpg → error_images
# ✅ Copied image_178.jpg → error_images
# ✅ Copied image_354.jpg → error_images
# ✅ Copied image_371.jpg → error_images
# ✅ Copied image_303.jpg → error_images
# ✅ Copied image_333.jpg → error_images
# ✅ Copied image_132.jpg → error_images
# ✅ Copied image_465.jpg → error_images
# ✅ Copied image_491.jpg → error_images
# ✅ Copied image_447.jpg → error_images
# ✅ Copied image_186.jpg → error_images
# ✅ Copied image_294.jpg → error_images
# ✅ Copied image_23.jpg → error_images
# ✅ Copied image_108.jpg → error_images
# ✅ Copied image_342.jpg → error_images
# ✅ Copied image_276.jpg → error_images
# ✅ Copied image_36.jpg → error_images
# ✅ Copied image_252.jpg → error_images
# ✅ Copied image_266.jpg → error_images
# ✅ Copied image_282.jpg → error_images
# ✅ Copied image_494.jpg → error_images
# ✅ Copied image_394.jpg → error_images
# ✅ Copied image_307.jpg → error_images
# ✅ Copied image_145.jpg → error_images
# ✅ Copied Image_10.jpg → error_images
# ✅ Copied image_64.jpg → error_images
# ✅ Copied image_162.jpg → error_images
# ✅ Copied image_117.jpg → error_images
# ✅ Copied image_137.jpg → error_images
# ✅ Copied image_225.jpg → error_images
# ✅ Copied image_205.jpg → error_images
# ✅ Copied image_115.jpg → error_images
# ✅ Copied image_110.jpg → error_images
# ✅ Copied image_39.jpg → error_images
# ✅ Copied image_231.jpg → error_images
# ✅ Copied image_198.jpg → error_images
# ✅ Copied image_326.jpg → error_images
# ✅ Copied image_272.jpg → error_images
# ✅ Copied image_79.jpg → error_images
# ✅ Copied image_350.jpg → error_images
# ✅ Copied image_189.jpg → error_images
# ✅ Copied image_167.jpg → error_images
# ✅ Copied image_293.jpg → error_images
# ✅ Copied image_417.jpg → error_images
# ✅ Copied image_173.jpg → error_images
# ✅ Copied image_391.jpg → error_images
# ✅ Copied image_268.jpg → error_images
# ✅ Copied image_300.jpg → error_images
# ✅ Copied Image_5.jpg → error_images
# ✅ Copied image_441.jpg → error_images
# ✅ Copied image_73.jpg → error_images
# ✅ Copied image_376.jpg → error_images
# ✅ Copied image_51.jpg → error_images
# ✅ Copied image_241.jpg → error_images
# ✅ Copied image_263.jpg → error_images
# ✅ Copied image_200.jpg → error_images
# ✅ Copied image_452.jpg → error_images
# ✅ Copied image_443.jpg → error_images
# ✅ Copied image_493.jpg → error_images
# ✅ Copied image_351.jpg → error_images
# ✅ Copied image_129.jpg → error_images
# ✅ Copied Image_16.jpg → error_images
# ✅ Copied image_332.jpg → error_images
# ✅ Copied image_31.jpg → error_images
# ✅ Copied image_168.jpg → error_images
# ✅ Copied image_361.jpg → error_images
# ✅ Copied image_152.jpg → error_images
# ✅ Copied image_84.jpg → error_images
# ✅ Copied image_197.jpg → error_images
# ✅ Copied image_42.jpg → error_images
# ✅ Copied image_311.jpg → error_images
# ✅ Copied image_195.jpg → error_images
# ✅ Copied image_440.jpg → error_images
# ✅ Copied image_308.jpg → error_images
# ✅ Copied image_457.jpg → error_images
# ✅ Copied image_207.jpg → error_images
# ✅ Copied image_57.jpg → error_images
# ✅ Copied Image_7.jpg → error_images
# ✅ Copied Image_20.jpg → error_images
# ✅ Copied Image_11.jpg → error_images
# ✅ Copied image_194.jpg → error_images
# ✅ Copied image_389.jpg → error_images
# ✅ Copied image_375.jpg → error_images
# ✅ Copied image_238.jpg → error_images
# ✅ Copied image_398.jpg → error_images
# ✅ Copied image_430.jpg → error_images
# ✅ Copied image_442.jpg → error_images
# ✅ Copied image_444.jpg → error_images
# ✅ Copied image_196.jpg → error_images
# ✅ Copied image_298.jpg → error_images
# ✅ Copied image_339.jpg → error_images
# ✅ Copied image_348.jpg → error_images
# ✅ Copied image_127.jpg → error_images
# ✅ Copied image_217.jpg → error_images
# ✅ Copied image_24.jpg → error_images
# ✅ Copied image_330.jpg → error_images
# ✅ Copied image_473.jpg → error_images
# ✅ Copied image_67.jpg → error_images
# ✅ Copied image_191.jpg → error_images
# ✅ Copied image_485.jpg → error_images
# ✅ Copied image_283.jpg → error_images
# ✅ Copied image_309.jpg → error_images
# ✅ Copied image_155.jpg → error_images
# ✅ Copied image_48.jpg → error_images
# ✅ Copied image_451.jpg → error_images
# ✅ Copied image_405.jpg → error_images
# ✅ Copied image_353.jpg → error_images
# ✅ Copied image_369.jpg → error_images
# ✅ Copied image_255.jpg → error_images
# ✅ Copied image_243.jpg → error_images
# ✅ Copied image_118.jpg → error_images
# ✅ Copied image_384.jpg → error_images
# ✅ Copied image_299.jpg → error_images
# ✅ Copied image_250.jpg → error_images
# ✅ Copied image_212.jpg → error_images
# ✅ Copied image_203.jpg → error_images
# ✅ Copied Image_12.jpg → error_images
# ✅ Copied image_156.jpg → error_images
# ✅ Copied image_63.jpg → error_images
# ✅ Copied image_82.jpg → error_images
# ✅ Copied image_171.jpg → error_images
# ✅ Copied Image_2.jpg → error_images
# ✅ Copied image_347.jpg → error_images
# ✅ Copied image_185.jpg → error_images
# ✅ Copied image_106.jpg → error_images
# ✅ Copied image_336.jpg → error_images
# ✅ Copied image_273.jpg → error_images
# ✅ Copied image_211.jpg → error_images
# ✅ Copied image_26.jpg → error_images
# ✅ Copied image_463.jpg → error_images
# ✅ Copied image_226.jpg → error_images
# ✅ Copied image_472.jpg → error_images
# ✅ Copied image_76.jpg → error_images
# ✅ Copied image_327.jpg → error_images
# ✅ Copied image_367.jpg → error_images
# ✅ Copied image_256.jpg → error_images
# ✅ Copied image_315.jpg → error_images
# ✅ Copied image_402.jpg → error_images
# ✅ Copied image_365.jpg → error_images
# ✅ Copied image_314.jpg → error_images
# ✅ Copied image_183.jpg → error_images
# ✅ Copied image_25.jpg → error_images
# ✅ Copied image_388.jpg → error_images
# ✅ Copied image_237.jpg → error_images
# ✅ Copied image_377.jpg → error_images
# ✅ Copied image_478.jpg → error_images
# ✅ Copied image_274.jpg → error_images
# ✅ Copied image_289.jpg → error_images
# ✅ Copied image_114.jpg → error_images
# ✅ Copied image_408.jpg → error_images
# ✅ Copied image_201.jpg → error_images
# ✅ Copied image_261.jpg → error_images
# ✅ Copied image_422.jpg → error_images
# ✅ Copied image_235.jpg → error_images
# ✅ Copied image_133.jpg → error_images
# ✅ Copied image_496.jpg → error_images
# ✅ Copied image_352.jpg → error_images
# ✅ Copied image_83.jpg → error_images
# ✅ Copied image_91.jpg → error_images
# ✅ Copied image_477.jpg → error_images
# ✅ Copied image_97.jpg → error_images
# ✅ Copied image_65.jpg → error_images
# ✅ Copied image_329.jpg → error_images
# ✅ Copied image_378.jpg → error_images
# ✅ Copied image_130.jpg → error_images
# ✅ Copied image_295.jpg → error_images
# ✅ Copied image_170.jpg → error_images
# ✅ Copied image_292.jpg → error_images
# ✅ Copied image_316.jpg → error_images
# ✅ Copied image_192.jpg → error_images
# ✅ Copied image_113.jpg → error_images
# ✅ Copied image_414.jpg → error_images
# ✅ Copied image_202.jpg → error_images
# ✅ Copied image_415.jpg → error_images
# ✅ Copied image_52.jpg → error_images
# ✅ Copied image_163.jpg → error_images
# ✅ Copied image_204.jpg → error_images
# ✅ Copied image_78.jpg → error_images
# ✅ Copied image_29.jpg → error_images
# ✅ Copied image_438.jpg → error_images
# ✅ Copied image_406.jpg → error_images
# ✅ Copied image_218.jpg → error_images
# ✅ Copied image_56.jpg → error_images
# ✅ Copied image_325.jpg → error_images
# ✅ Copied image_411.jpg → error_images
# ✅ Copied image_135.jpg → error_images
# ✅ Copied image_281.jpg → error_images
# ✅ Copied image_482.jpg → error_images
# ✅ Copied image_94.jpg → error_images
# ✅ Copied image_216.jpg → error_images
# ✅ Copied image_260.jpg → error_images
# ✅ Copied image_486.jpg → error_images
# ✅ Copied image_157.jpg → error_images
# ✅ Copied image_103.jpg → error_images
# ✅ Copied image_102.jpg → error_images
# ✅ Copied image_34.jpg → error_images
# ✅ Copied image_101.jpg → error_images
# ✅ Copied image_254.jpg → error_images
# ✅ Copied image_27.jpg → error_images
# ✅ Copied image_395.jpg → error_images
# ✅ Copied image_71.jpg → error_images
# ✅ Copied image_464.jpg → error_images
# ✅ Copied image_306.jpg → error_images
# ✅ Copied Image_8.png → error_images
# ✅ Copied image_490.jpg → error_images
# ✅ Copied image_85.jpg → error_images
# ✅ Copied image_249.jpg → error_images
# ✅ Copied image_338.jpg → error_images
# ✅ Copied image_193.jpg → error_images
# ✅ Copied image_87.jpg → error_images
# ✅ Copied image_426.jpg → error_images
# ✅ Copied image_37.jpg → error_images
# ✅ Copied image_88.jpg → error_images
# ✅ Copied image_290.jpg → error_images
# ✅ Copied image_165.jpg → error_images
# ✅ Copied image_141.jpg → error_images
# ✅ Copied image_370.jpg → error_images
# ✅ Copied Image_1.jpg → error_images
# ✅ Copied image_229.jpg → error_images
# ✅ Copied image_150.jpg → error_images
# ✅ Copied image_304.jpg → error_images
# ✅ Copied image_412.jpg → error_images
# ✅ Copied image_144.jpg → error_images
# ✅ Copied image_164.jpg → error_images
# ✅ Copied image_461.jpg → error_images
# ✅ Copied image_146.jpg → error_images
# ✅ Copied image_312.jpg → error_images
# ✅ Copied image_105.jpg → error_images
# ✅ Copied image_38.jpg → error_images
# ✅ Copied GradeC (128).jpg → 8cell_grade_C
# ✅ Copied Gradec (11).jpg → 8cell_grade_C
# ✅ Copied GradeC (63).jpg → 8cell_grade_C
# ✅ Copied GradeC (21).jpg → 8cell_grade_C
# ✅ Copied GradeC (101).jpg → 8cell_grade_C
# ✅ Copied GradeC (70).jpg → 8cell_grade_C
# ✅ Copied 8C_C (18).jpg → 8cell_grade_C
# ✅ Copied GradeC (106).jpg → 8cell_grade_C
# ✅ Copied GradeC (68).jpg → 8cell_grade_C
# ✅ Copied GradeC (34).jpg → 8cell_grade_C
# ✅ Copied GradeC (56).jpg → 8cell_grade_C
# ✅ Copied GradeC (5).jpg → 8cell_grade_C
# ✅ Copied GradeC (112).jpg → 8cell_grade_C
# ✅ Copied GradeC (64).jpg → 8cell_grade_C
# ✅ Copied GradeC (73).jpg → 8cell_grade_C
# ✅ Copied 8C_C (8).jpg → 8cell_grade_C
# ✅ Copied GradeC (87).jpg → 8cell_grade_C
# ✅ Copied GradeC (118).jpg → 8cell_grade_C
# ✅ Copied GradeC (26).jpg → 8cell_grade_C
# ✅ Copied Gradec (77).jpg → 8cell_grade_C
# ✅ Copied 8C_C (17).jpg → 8cell_grade_C
# ✅ Copied GradeC (41).jpg → 8cell_grade_C
# ✅ Copied 8C_C20.jpg → 8cell_grade_C
# ✅ Copied GradeC (19).jpg → 8cell_grade_C
# ✅ Copied GradeC (90).jpg → 8cell_grade_C
# ✅ Copied GradeC (12).jpg → 8cell_grade_C
# ✅ Copied GradeC (125).jpg → 8cell_grade_C
# ✅ Copied GradeC (47).jpg → 8cell_grade_C
# ✅ Copied 8C_C (12).jpg → 8cell_grade_C
# ✅ Copied GradeC (69).jpg → 8cell_grade_C
# ✅ Copied 8C_C(22).jpg → 8cell_grade_C
# ✅ Copied 8C_C (19).jpg → 8cell_grade_C
# ✅ Copied GradeC (92).jpg → 8cell_grade_C
# ✅ Copied GradeC (78).jpg → 8cell_grade_C
# ✅ Copied GradeC (59).jpg → 8cell_grade_C
# ✅ Copied GradeC (4).jpg → 8cell_grade_C
# ✅ Copied GradeC (97).jpg → 8cell_grade_C
# ✅ Copied GradeC (38).jpg → 8cell_grade_C
# ✅ Copied GradeC (76).jpg → 8cell_grade_C
# ✅ Copied GradeC (82).jpg → 8cell_grade_C
# ✅ Copied GradeC (88).jpg → 8cell_grade_C
# ✅ Copied GradeC (42).jpg → 8cell_grade_C
# ✅ Copied GradeC (115).jpg → 8cell_grade_C
# ✅ Copied GradeC (6).jpg → 8cell_grade_C
# ✅ Copied GradeC (124).jpg → 8cell_grade_C
# ✅ Copied GradeC (16).jpg → 8cell_grade_C
# ✅ Copied GradeC (85).jpg → 8cell_grade_C
# ✅ Copied GradeC (130).jpg → 8cell_grade_C
# ✅ Copied GradeC (83).jpg → 8cell_grade_C
# ✅ Copied GradeC (51).jpg → 8cell_grade_C
# ✅ Copied GradeC (126).jpg → 8cell_grade_C
# ✅ Copied GradeC (54).jpg → 8cell_grade_C
# ✅ Copied 8C_C (15).jpg → 8cell_grade_C
# ✅ Copied GradeC (80).jpg → 8cell_grade_C
# ✅ Copied GradeC (37).jpg → 8cell_grade_C
# ✅ Copied GradeC (103).jpg → 8cell_grade_C
# ✅ Copied 8C_C (4).jpg → 8cell_grade_C
# ✅ Copied 8C_c (6).jpg → 8cell_grade_C
# ✅ Copied GradeC (66).jpg → 8cell_grade_C
# ✅ Copied GradeC (58).jpg → 8cell_grade_C
# ✅ Copied GradeC (86).jpg → 8cell_grade_C
# ✅ Copied GradeC (23).jpg → 8cell_grade_C
# ✅ Copied 8C_C (13).jpg → 8cell_grade_C
# ✅ Copied GradeC (111).jpg → 8cell_grade_C
# ✅ Copied GradeC (114).jpg → 8cell_grade_C
# ✅ Copied 8C_C.jpg → 8cell_grade_C
# ✅ Copied GradeC (127).jpg → 8cell_grade_C
# ✅ Copied GradeC (24).jpg → 8cell_grade_C
# ✅ Copied GradeC (18).jpg → 8cell_grade_C
# ✅ Copied GradeC (55).jpg → 8cell_grade_C
# ✅ Copied 8C_C (23).jpg → 8cell_grade_C
# ✅ Copied 8C_c (7).jpg → 8cell_grade_C
# ✅ Copied GradeC (27).jpg → 8cell_grade_C
# ✅ Copied GradeC (98).jpg → 8cell_grade_C
# ✅ Copied GradeC (133).jpg → 8cell_grade_C
# ✅ Copied GradeC (89).jpg → 8cell_grade_C
# ✅ Copied GradeC (100).jpg → 8cell_grade_C
# ✅ Copied GradeC (91).jpg → 8cell_grade_C
# ✅ Copied GradeC (99).jpg → 8cell_grade_C
# ✅ Copied GradeC (30).jpg → 8cell_grade_C
# ✅ Copied GradeC (32).jpg → 8cell_grade_C
# ✅ Copied GradeC (81).jpg → 8cell_grade_C
# ✅ Copied GradeC (95).jpg → 8cell_grade_C
# ✅ Copied GradeC (31).jpg → 8cell_grade_C
# ✅ Copied GradeC (102).jpg → 8cell_grade_C
# ✅ Copied GradeC (25).jpg → 8cell_grade_C
# ✅ Copied GradeC (15).jpg → 8cell_grade_C
# ✅ Copied GradeC (33).jpg → 8cell_grade_C
# ✅ Copied GradeC (62).jpg → 8cell_grade_C
# ✅ Copied GradeC (50).jpg → 8cell_grade_C
# ✅ Copied GradeC (39).jpg → 8cell_grade_C
# ✅ Copied 8C_C (5).jpg → 8cell_grade_C
# ✅ Copied GradeC (28).jpg → 8cell_grade_C
# ✅ Copied GradeC (57).jpg → 8cell_grade_C
# ✅ Copied GradeC (8).jpg → 8cell_grade_C
# ✅ Copied GradeC (94).jpg → 8cell_grade_C
# ✅ Copied GradeC (122).jpg → 8cell_grade_C
# ✅ Copied GradeC (7).jpg → 8cell_grade_C
# ✅ Copied GradeC (46).jpg → 8cell_grade_C
# ✅ Copied GradeC (84).jpg → 8cell_grade_C
# ✅ Copied GradeC (44).jpg → 8cell_grade_C
# ✅ Copied 8C_C (2).jpg → 8cell_grade_C
# ✅ Copied GradeC (36).jpg → 8cell_grade_C
# ✅ Copied GradeC (2).jpg → 8cell_grade_C
# ✅ Copied GradeC (40).jpg → 8cell_grade_C
# ✅ Copied GradeC (75).jpg → 8cell_grade_C
# ✅ Copied 8C_C (11).jpg → 8cell_grade_C
# ✅ Copied GradeC (131).jpg → 8cell_grade_C
# ✅ Copied GradeC (20).jpg → 8cell_grade_C
# ✅ Copied GradeC (3).jpg → 8cell_grade_C
# ✅ Copied GradeC (17).jpg → 8cell_grade_C
# ✅ Copied 8C_C (3).jpg → 8cell_grade_C
# ✅ Copied GradeC (132).jpg → 8cell_grade_C
# ✅ Copied GradeC (29).jpg → 8cell_grade_C
# ✅ Copied GradeC (117).jpg → 8cell_grade_C
# ✅ Copied GradeC (14).jpg → 8cell_grade_C
# ✅ Copied GradeC (43).jpg → 8cell_grade_C
# ✅ Copied GradeC (9).jpg → 8cell_grade_C
# ✅ Copied GradeC (71).jpg → 8cell_grade_C
# ✅ Copied GradeC (52).jpg → 8cell_grade_C
# ✅ Copied 8C_C (10).jpg → 8cell_grade_C
# ✅ Copied GradeC (10).jpg → 8cell_grade_C
# ✅ Copied GradeC (72).jpg → 8cell_grade_C
# ✅ Copied GradeC (49).jpg → 8cell_grade_C
# ✅ Copied GradeC (60).jpg → 8cell_grade_C
# ✅ Copied GradeC (79).jpg → 8cell_grade_C
# ✅ Copied 8C_C (9).jpg → 8cell_grade_C
# ✅ Copied 8C_C (14).jpg → 8cell_grade_C
# ✅ Copied GradeC (104).jpg → 8cell_grade_C
# ✅ Copied GradeC (45).jpg → 8cell_grade_C
# ✅ Copied GradeC (116).jpg → 8cell_grade_C
# ✅ Copied GradeC (129).jpg → 8cell_grade_C
# ✅ Copied 8C_C (21).jpg → 8cell_grade_C
# ✅ Copied GradeC (22).jpg → 8cell_grade_C
# ✅ Copied GradeC (96).jpg → 8cell_grade_C
# ✅ Copied 8C_C (24).jpg → 8cell_grade_C
# ✅ Copied GradeC (123).jpg → 8cell_grade_C
# ✅ Copied GradeC (61).jpg → 8cell_grade_C
# ✅ Copied GradeC (113).jpg → 8cell_grade_C
# ✅ Copied GradeC (48).jpg → 8cell_grade_C
# ✅ Copied GradeC (35).jpg → 8cell_grade_C
# ✅ Copied GradeC (53).jpg → 8cell_grade_C
# ✅ Copied GradeC (65).jpg → 8cell_grade_C
# ✅ Copied GradeC (13).jpg → 8cell_grade_C
# ✅ Copied GradeC (93).jpg → 8cell_grade_C
# ✅ Copied GradeC (110).jpg → 8cell_grade_C
# ✅ Copied GradeC (105).jpg → 8cell_grade_C
# ✅ Copied 8C_C (16).jpg → 8cell_grade_C
# ✅ Copied GradeC (67).jpg → 8cell_grade_C
# ✅ Copied GradeC (74).jpg → 8cell_grade_C
# ✅ Copied GradeB (46).jpg → 8cell_grade_B
# ✅ Copied GradeB (29).jpg → 8cell_grade_B
# ✅ Copied 8C_B(19).jpg → 8cell_grade_B
# ✅ Copied GradeB (19).jpg → 8cell_grade_B
# ✅ Copied GradeB (131).jpg → 8cell_grade_B
# ✅ Copied 8C_b (3).jpg → 8cell_grade_B
# ✅ Copied GradeB (79).jpg → 8cell_grade_B
# ✅ Copied GradeB (26).jpg → 8cell_grade_B
# ✅ Copied GradeB (44).jpg → 8cell_grade_B
# ✅ Copied GradeB (6).jpg → 8cell_grade_B
# ✅ Copied GradeB (106).jpg → 8cell_grade_B
# ✅ Copied GradeB (7).jpg → 8cell_grade_B
# ✅ Copied GradeB (37).jpg → 8cell_grade_B
# ✅ Copied GradeB (98).jpg → 8cell_grade_B
# ✅ Copied GradeB (56).jpg → 8cell_grade_B
# ✅ Copied GradeB (65).jpg → 8cell_grade_B
# ✅ Copied GradeB (76).jpg → 8cell_grade_B
# ✅ Copied GradeB (63).jpg → 8cell_grade_B
# ✅ Copied GradeB (84).jpg → 8cell_grade_B
# ✅ Copied 8C_B(20).jpg → 8cell_grade_B
# ✅ Copied GradeB (132).jpg → 8cell_grade_B
# ✅ Copied GradeB (97).jpg → 8cell_grade_B
# ✅ Copied GradeB (50).jpg → 8cell_grade_B
# ✅ Copied 8C_B (15).jpg → 8cell_grade_B
# ✅ Copied GradeB (4).jpg → 8cell_grade_B
# ✅ Copied GradeB (5).jpg → 8cell_grade_B
# ✅ Copied GradeB (36).jpg → 8cell_grade_B
# ✅ Copied GradeB (126).jpg → 8cell_grade_B
# ✅ Copied GradeB (42).jpg → 8cell_grade_B
# ✅ Copied GradeB (51).jpg → 8cell_grade_B
# ✅ Copied 8C_B(18).jpg → 8cell_grade_B
# ✅ Copied GradeB (67).jpg → 8cell_grade_B
# ✅ Copied GradeB (28).jpg → 8cell_grade_B
# ✅ Copied GradeB (48).jpg → 8cell_grade_B
# ✅ Copied GradeB (24).jpg → 8cell_grade_B
# ✅ Copied GradeB (101).jpg → 8cell_grade_B
# ✅ Copied GradeB (73).jpg → 8cell_grade_B
# ✅ Copied GradeB (23).jpg → 8cell_grade_B
# ✅ Copied GradeB (62).jpg → 8cell_grade_B
# ✅ Copied GradeB (92).jpg → 8cell_grade_B
# ✅ Copied GradeB (128).jpg → 8cell_grade_B
# ✅ Copied GradeB (103).jpg → 8cell_grade_B
# ✅ Copied GradeB (91).jpg → 8cell_grade_B
# ✅ Copied GradeB (99).jpg → 8cell_grade_B
# ✅ Copied GradeB (83).jpg → 8cell_grade_B
# ✅ Copied GradeB (86).jpg → 8cell_grade_B
# ✅ Copied GradeB (78).jpg → 8cell_grade_B
# ✅ Copied GradeB (59).jpg → 8cell_grade_B
# ✅ Copied GradeB (43).jpg → 8cell_grade_B
# ✅ Copied GradeB (8).jpg → 8cell_grade_B
# ✅ Copied GradeB (32).jpg → 8cell_grade_B
# ✅ Copied GradeB (2).jpg → 8cell_grade_B
# ✅ Copied 8C_B (8).jpg → 8cell_grade_B
# ✅ Copied GradeB (102).jpg → 8cell_grade_B
# ✅ Copied GradeB (133).jpg → 8cell_grade_B
# ✅ Copied GradeB (68).jpg → 8cell_grade_B
# ✅ Copied GradeB (112).jpg → 8cell_grade_B
# ✅ Copied GradeB (90).jpg → 8cell_grade_B
# ✅ Copied GradeB (60).jpg → 8cell_grade_B
# ✅ Copied GradeB (55).jpg → 8cell_grade_B
# ✅ Copied GradeB (54).jpg → 8cell_grade_B
# ✅ Copied GradeB (116).jpg → 8cell_grade_B
# ✅ Copied GradeB (81).jpg → 8cell_grade_B
# ✅ Copied GradeB (119).jpg → 8cell_grade_B
# ✅ Copied GradeB (127).jpg → 8cell_grade_B
# ✅ Copied GradeB (100).jpg → 8cell_grade_B
# ✅ Copied GradeB (9).jpg → 8cell_grade_B
# ✅ Copied GradeB (85).jpg → 8cell_grade_B
# ✅ Copied GradeB (49).jpg → 8cell_grade_B
# ✅ Copied GradeB (77).jpg → 8cell_grade_B
# ✅ Copied GradeB (33).jpg → 8cell_grade_B
# ✅ Copied GradeB (39).jpg → 8cell_grade_B
# ✅ Copied GradeB (75).jpg → 8cell_grade_B
# ✅ Copied GradeB (104).jpg → 8cell_grade_B
# ✅ Copied GradeB (66).jpg → 8cell_grade_B
# ✅ Copied GradeB (13).jpg → 8cell_grade_B
# ✅ Copied GradeB (120).jpg → 8cell_grade_B
# ✅ Copied GradeB (108).jpg → 8cell_grade_B
# ✅ Copied GradeB (12).jpg → 8cell_grade_B
# ✅ Copied GradeB (18).jpg → 8cell_grade_B
# ✅ Copied 8C_B (12).jpg → 8cell_grade_B
# ✅ Copied GradeB (25).jpg → 8cell_grade_B
# ✅ Copied GradeB (53).jpg → 8cell_grade_B
# ✅ Copied GradeB (69).jpg → 8cell_grade_B
# ✅ Copied 8C_B (16).jpg → 8cell_grade_B
# ✅ Copied 8C_B (11).jpg → 8cell_grade_B
# ✅ Copied GradeB (34).jpg → 8cell_grade_B
# ✅ Copied GradeB (31).jpg → 8cell_grade_B
# ✅ Copied 8C_B (10).jpg → 8cell_grade_B
# ✅ Copied GradeB (72).jpg → 8cell_grade_B
# ✅ Copied GradeB (107).jpg → 8cell_grade_B
# ✅ Copied 8C_B (2).jpg → 8cell_grade_B
# ✅ Copied GradeB (11).jpg → 8cell_grade_B
# ✅ Copied GradeB (64).jpg → 8cell_grade_B
# ✅ Copied GradeB (117).jpg → 8cell_grade_B
# ✅ Copied GradeB (15).jpg → 8cell_grade_B
# ✅ Copied GradeB (96).jpg → 8cell_grade_B
# ✅ Copied GradeB (93).jpg → 8cell_grade_B
# ✅ Copied GradeB (21).jpg → 8cell_grade_B
# ✅ Copied GradeB (22).jpg → 8cell_grade_B
# ✅ Copied GradeB (16).jpg → 8cell_grade_B
# ✅ Copied GradeB (58).jpg → 8cell_grade_B
# ✅ Copied 8C_B(21).jpg → 8cell_grade_B
# ✅ Copied GradeB (45).jpg → 8cell_grade_B
# ✅ Copied 8C_B (17).jpg → 8cell_grade_B
# ✅ Copied GradeB (61).jpg → 8cell_grade_B
# ✅ Copied GradeB (121).jpg → 8cell_grade_B
# ✅ Copied GradeB (14).jpg → 8cell_grade_B
# ✅ Copied GradeB (17).jpg → 8cell_grade_B
# ✅ Copied GradeB (134).jpg → 8cell_grade_B
# ✅ Copied GradeB (82).jpg → 8cell_grade_B
# ✅ Copied GradeB (115).jpg → 8cell_grade_B
# ✅ Copied GradeB (20).jpg → 8cell_grade_B
# ✅ Copied 8C_B (4).jpg → 8cell_grade_B
# ✅ Copied GradeB (3).jpg → 8cell_grade_B
# ✅ Copied 8C_B (14).jpg → 8cell_grade_B
# ✅ Copied GradeB (113).jpg → 8cell_grade_B
# ✅ Copied GradeB (40).jpg → 8cell_grade_B
# ✅ Copied 8C_B (7).jpg → 8cell_grade_B
# ✅ Copied GradeB (105).jpg → 8cell_grade_B
# ✅ Copied GradeB (80).jpg → 8cell_grade_B
# ✅ Copied GradeB (110).jpg → 8cell_grade_B
# ✅ Copied GradeB (89).jpg → 8cell_grade_B
# ✅ Copied GradeB (47).jpg → 8cell_grade_B
# ✅ Copied GradeB (35).jpg → 8cell_grade_B
# ✅ Copied GradeB (70).jpg → 8cell_grade_B
# ✅ Copied GradeB (52).jpg → 8cell_grade_B
# ✅ Copied GradeB (94).jpg → 8cell_grade_B
# ✅ Copied GradeB (88).jpg → 8cell_grade_B
# ✅ Copied GradeB (38).jpg → 8cell_grade_B
# ✅ Copied GradeB (122).jpg → 8cell_grade_B
# ✅ Copied GradeB (118).jpg → 8cell_grade_B
# ✅ Copied 8C_B (13).jpg → 8cell_grade_B
# ✅ Copied GradeB (10).jpg → 8cell_grade_B
# ✅ Copied GradeB (114).jpg → 8cell_grade_B
# ✅ Copied GradeB (41).jpg → 8cell_grade_B
# ✅ Copied GradeB (87).jpg → 8cell_grade_B
# ✅ Copied 8C_B (9).jpg → 8cell_grade_B
# ✅ Copied GradeB (111).jpg → 8cell_grade_B
# ✅ Copied GradeB (71).jpg → 8cell_grade_B
# ✅ Copied GradeB (57).jpg → 8cell_grade_B
# ✅ Copied GradeB (27).jpg → 8cell_grade_B
# ✅ Copied GradeB (95).jpg → 8cell_grade_B
# ✅ Copied GradeB (129).jpg → 8cell_grade_B
# ✅ Copied 8C_B (6).jpg → 8cell_grade_B
# ✅ Copied GradeB (30).jpg → 8cell_grade_B
# ✅ Copied 8C_B (5).jpg → 8cell_grade_B
# ✅ Copied GradeB (130).jpg → 8cell_grade_B
# ✅ Copied GradeB (74).jpg → 8cell_grade_B
# ✅ Copied GradeB (109).jpg → 8cell_grade_B
# ✅ Copied GradeA (98).jpg → 8cell_grade_A
# ✅ Copied GradeA (78).jpg → 8cell_grade_A
# ✅ Copied 8c_a (36).jpg → 8cell_grade_A
# ✅ Copied GradeA (75).jpg → 8cell_grade_A
# ✅ Copied GradeA (140).jpg → 8cell_grade_A
# ✅ Copied 8C_A (37).jpg → 8cell_grade_A
# ✅ Copied GradeA (89).jpg → 8cell_grade_A
# ✅ Copied GradeA (137).jpg → 8cell_grade_A
# ✅ Copied GradeA (65).jpg → 8cell_grade_A
# ✅ Copied 8C_A (25).jpg → 8cell_grade_A
# ✅ Copied 8C_A (2).jpg → 8cell_grade_A
# ✅ Copied GradeA (54).jpg → 8cell_grade_A
# ✅ Copied GradeA (79).jpg → 8cell_grade_A
# ✅ Copied GradeA (9).jpg → 8cell_grade_A
# ✅ Copied GradeA (124).jpg → 8cell_grade_A
# ✅ Copied 8C_a (27).jpg → 8cell_grade_A
# ✅ Copied 8C_a (30).jpg → 8cell_grade_A
# ✅ Copied GradeA (48).jpg → 8cell_grade_A
# ✅ Copied 8C_A (16).jpg → 8cell_grade_A
# ✅ Copied GradeA (103).jpg → 8cell_grade_A
# ✅ Copied 8C_A (8).jpg → 8cell_grade_A
# ✅ Copied GradeA (66).jpg → 8cell_grade_A
# ✅ Copied GradeA (32).jpg → 8cell_grade_A
# ✅ Copied GradeA (13).jpg → 8cell_grade_A
# ✅ Copied GradeA (123).jpg → 8cell_grade_A
# ✅ Copied GradeA (42).jpg → 8cell_grade_A
# ✅ Copied GradeA (19).jpg → 8cell_grade_A
# ✅ Copied GradeA (68).jpg → 8cell_grade_A
# ✅ Copied GradeA (51).jpg → 8cell_grade_A
# ✅ Copied GradeA (4).jpg → 8cell_grade_A
# ✅ Copied 8C_A (12).jpg → 8cell_grade_A
# ✅ Copied GradeA (111).jpg → 8cell_grade_A
# ✅ Copied GradeA (43).jpg → 8cell_grade_A
# ✅ Copied GradeA (52).jpg → 8cell_grade_A
# ✅ Copied GradeA (127).jpg → 8cell_grade_A
# ✅ Copied 8C_A (24).jpg → 8cell_grade_A
# ✅ Copied 8C_A (23).jpg → 8cell_grade_A
# ✅ Copied GradeA (49).jpg → 8cell_grade_A
# ✅ Copied GradeA (138).jpg → 8cell_grade_A
# ✅ Copied GradeA (64).jpg → 8cell_grade_A
# ✅ Copied GradeA (59).jpg → 8cell_grade_A
# ✅ Copied 8C_A (3).jpg → 8cell_grade_A
# ✅ Copied GradeA (2).jpg → 8cell_grade_A
# ✅ Copied GradeA (112).jpg → 8cell_grade_A
# ✅ Copied GradeA (115).jpg → 8cell_grade_A
# ✅ Copied GradeA (99).jpg → 8cell_grade_A
# ✅ Copied GradeA (20).jpg → 8cell_grade_A
# ✅ Copied GradeA (77).jpg → 8cell_grade_A
# ✅ Copied GradeA (86).jpg → 8cell_grade_A
# ✅ Copied GradeA (102).jpg → 8cell_grade_A
# ✅ Copied GradeA (10).jpg → 8cell_grade_A
# ✅ Copied 8C_A (26).jpg → 8cell_grade_A
# ✅ Copied GradeA (28).jpg → 8cell_grade_A
# ✅ Copied 8C_A (22).jpg → 8cell_grade_A
# ✅ Copied GradeA (136).jpg → 8cell_grade_A
# ✅ Copied GradeA (11).jpg → 8cell_grade_A
# ✅ Copied GradeA (17).jpg → 8cell_grade_A
# ✅ Copied 8C_A (39).jpg → 8cell_grade_A
# ✅ Copied GradeA (122).jpg → 8cell_grade_A
# ✅ Copied GradeA (40).jpg → 8cell_grade_A
# ✅ Copied GradeA (101).jpg → 8cell_grade_A
# ✅ Copied GradeA (113).jpg → 8cell_grade_A
# ✅ Copied GradeA (76).jpg → 8cell_grade_A
# ✅ Copied GradeA (63).jpg → 8cell_grade_A
# ✅ Copied GradeA (87).jpg → 8cell_grade_A
# ✅ Copied GradeA (36).jpg → 8cell_grade_A
# ✅ Copied 8C_A (7).jpg → 8cell_grade_A
# ✅ Copied GradeA (57).jpg → 8cell_grade_A
# ✅ Copied GradeA (92).jpg → 8cell_grade_A
# ✅ Copied GradeA (24).jpg → 8cell_grade_A
# ✅ Copied GradeA (62).jpg → 8cell_grade_A
# ✅ Copied 8C_A (21).jpg → 8cell_grade_A
# ✅ Copied 8C_A (35).jpg → 8cell_grade_A
# ✅ Copied 8C_A (5).jpg → 8cell_grade_A
# ✅ Copied GradeA (125).jpg → 8cell_grade_A
# ✅ Copied GradeA (50).jpg → 8cell_grade_A
# ✅ Copied GradeA (114).jpg → 8cell_grade_A
# ✅ Copied GradeA (60).jpg → 8cell_grade_A
# ✅ Copied GradeA (25).jpg → 8cell_grade_A
# ✅ Copied GradeA (23).jpg → 8cell_grade_A
# ✅ Copied GradeA (41).jpg → 8cell_grade_A
# ✅ Copied GradeA (27).jpg → 8cell_grade_A
# ✅ Copied GradeA (90).jpg → 8cell_grade_A
# ✅ Copied 8C_a (29).jpg → 8cell_grade_A
# ✅ Copied 8C_a (31).jpg → 8cell_grade_A
# ✅ Copied 8C_A (13).jpg → 8cell_grade_A
# ✅ Copied GradeA (30).jpg → 8cell_grade_A
# ✅ Copied GradeA (18).jpg → 8cell_grade_A
# ✅ Copied 8C_A (14).jpg → 8cell_grade_A
# ✅ Copied GradeA (116).jpg → 8cell_grade_A
# ✅ Copied 8c_a (33).jpg → 8cell_grade_A
# ✅ Copied GradeA (38).jpg → 8cell_grade_A
# ✅ Copied GradeA (74).jpg → 8cell_grade_A
# ✅ Copied 8C_a (32).jpg → 8cell_grade_A
# ✅ Copied GradeA (134).jpg → 8cell_grade_A
# ✅ Copied GradeA (5).jpg → 8cell_grade_A
# ✅ Copied 8C_A (10).jpg → 8cell_grade_A
# ✅ Copied 8C_A (40).jpg → 8cell_grade_A
# ✅ Copied GradeA (126).jpg → 8cell_grade_A
# ✅ Copied GradeA (22).jpg → 8cell_grade_A
# ✅ Copied 8C_A (4).jpg → 8cell_grade_A
# ✅ Copied 8C_A (11).jpg → 8cell_grade_A
# ✅ Copied GradeA (33).jpg → 8cell_grade_A
# ✅ Copied GradeA (35).jpg → 8cell_grade_A
# ✅ Copied GradeA (104).jpg → 8cell_grade_A
# ✅ Copied GradeA (3).jpg → 8cell_grade_A
# ...
# ✅ Copied GradeB (78).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (59).jpg
# ✅ Copied GradeB (43).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (8).jpg
# 🔁 Skipped duplicate: GradeB (32).jpg
# 🔁 Skipped duplicate: GradeB (2).jpg
# 🔁 Skipped duplicate: 8C_B (8).jpg
# ✅ Copied GradeB (102).jpg → 8cell_grade_B
# ✅ Copied GradeB (133).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (68).jpg
# 🔁 Skipped duplicate: GradeB (112).jpg
# ✅ Copied GradeB (90).jpg → 8cell_grade_B
# ✅ Copied GradeB (60).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (55).jpg
# ✅ Copied GradeB (54).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (116).jpg
# 🔁 Skipped duplicate: GradeB (81).jpg
# ✅ Copied GradeB (119).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (127).jpg
# ✅ Copied GradeB (100).jpg → 8cell_grade_B
# ✅ Copied GradeB (9).jpg → 8cell_grade_B
# ✅ Copied GradeB (85).jpg → 8cell_grade_B
# ✅ Copied GradeB (49).jpg → 8cell_grade_B
# ✅ Copied GradeB (77).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (33).jpg
# 🔁 Skipped duplicate: GradeB (39).jpg
# 🔁 Skipped duplicate: GradeB (75).jpg
# ✅ Copied GradeB (104).jpg → 8cell_grade_B
# ✅ Copied GradeB (66).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (13).jpg
# ✅ Copied GradeB (120).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (108).jpg
# ✅ Copied GradeB (12).jpg → 8cell_grade_B
# ✅ Copied GradeB (18).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (12).jpg
# ✅ Copied GradeB (25).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (53).jpg
# ✅ Copied GradeB (69).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (16).jpg
# 🔁 Skipped duplicate: 8C_B (11).jpg
# ✅ Copied GradeB (34).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (31).jpg
# 🔁 Skipped duplicate: 8C_B (10).jpg
# ✅ Copied GradeB (72).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (107).jpg
# 🔁 Skipped duplicate: 8C_B (2).jpg
# 🔁 Skipped duplicate: GradeB (11).jpg
# ✅ Copied GradeB (64).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (117).jpg
# 🔁 Skipped duplicate: GradeB (15).jpg
# ✅ Copied GradeB (96).jpg → 8cell_grade_B
# ✅ Copied GradeB (93).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (21).jpg
# ✅ Copied GradeB (22).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (16).jpg
# 🔁 Skipped duplicate: GradeB (58).jpg
# 🔁 Skipped duplicate: 8C_B(21).jpg
# ✅ Copied GradeB (45).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (17).jpg
# ✅ Copied GradeB (61).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (121).jpg
# ✅ Copied GradeB (14).jpg → 8cell_grade_B
# ✅ Copied GradeB (17).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (134).jpg
# ✅ Copied GradeB (82).jpg → 8cell_grade_B
# ✅ Copied GradeB (115).jpg → 8cell_grade_B
# ✅ Copied GradeB (20).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (4).jpg
# ✅ Copied GradeB (3).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (14).jpg
# 🔁 Skipped duplicate: GradeB (113).jpg
# ✅ Copied GradeB (40).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (7).jpg
# ✅ Copied GradeB (105).jpg → 8cell_grade_B
# ✅ Copied GradeB (80).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (110).jpg
# 🔁 Skipped duplicate: GradeB (89).jpg
# ✅ Copied GradeB (47).jpg → 8cell_grade_B
# ✅ Copied GradeB (35).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (70).jpg
# ✅ Copied GradeB (52).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (94).jpg
# ✅ Copied GradeB (88).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (38).jpg
# ✅ Copied GradeB (122).jpg → 8cell_grade_B
# ✅ Copied GradeB (118).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (13).jpg
# ✅ Copied GradeB (10).jpg → 8cell_grade_B
# ✅ Copied GradeB (114).jpg → 8cell_grade_B
# ✅ Copied GradeB (41).jpg → 8cell_grade_B
# ✅ Copied GradeB (87).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: 8C_B (9).jpg
# ✅ Copied GradeB (111).jpg → 8cell_grade_B
# ✅ Copied GradeB (71).jpg → 8cell_grade_B
# ✅ Copied GradeB (57).jpg → 8cell_grade_B
# ✅ Copied GradeB (27).jpg → 8cell_grade_B
# ✅ Copied GradeB (95).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeB (129).jpg
# 🔁 Skipped duplicate: 8C_B (6).jpg
# 🔁 Skipped duplicate: GradeB (30).jpg
# 🔁 Skipped duplicate: 8C_B (5).jpg
# ✅ Copied GradeB (130).jpg → 8cell_grade_B
# ✅ Copied GradeB (74).jpg → 8cell_grade_B
# ✅ Copied GradeB (109).jpg → 8cell_grade_B
# 🔁 Skipped duplicate: GradeA (98).jpg
# 🔁 Skipped duplicate: GradeA (78).jpg
# 🔁 Skipped duplicate: 8c_a (36).jpg
# 🔁 Skipped duplicate: GradeA (75).jpg
# 🔁 Skipped duplicate: GradeA (140).jpg
# 🔁 Skipped duplicate: 8C_A (37).jpg
# 🔁 Skipped duplicate: GradeA (89).jpg
# 🔁 Skipped duplicate: GradeA (137).jpg
# 🔁 Skipped duplicate: GradeA (65).jpg
# 🔁 Skipped duplicate: 8C_A (25).jpg
# 🔁 Skipped duplicate: 8C_A (2).jpg
# 🔁 Skipped duplicate: GradeA (54).jpg
# ✅ Copied GradeA (79).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (9).jpg
# 🔁 Skipped duplicate: GradeA (124).jpg
# 🔁 Skipped duplicate: 8C_a (27).jpg
# 🔁 Skipped duplicate: 8C_a (30).jpg
# 🔁 Skipped duplicate: GradeA (48).jpg
# 🔁 Skipped duplicate: 8C_A (16).jpg
# 🔁 Skipped duplicate: GradeA (103).jpg
# 🔁 Skipped duplicate: 8C_A (8).jpg
# ✅ Copied GradeA (66).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (32).jpg
# 🔁 Skipped duplicate: GradeA (13).jpg
# 🔁 Skipped duplicate: GradeA (123).jpg
# 🔁 Skipped duplicate: GradeA (42).jpg
# 🔁 Skipped duplicate: GradeA (19).jpg
# 🔁 Skipped duplicate: GradeA (68).jpg
# 🔁 Skipped duplicate: GradeA (51).jpg
# 🔁 Skipped duplicate: GradeA (4).jpg
# 🔁 Skipped duplicate: 8C_A (12).jpg
# 🔁 Skipped duplicate: GradeA (111).jpg
# 🔁 Skipped duplicate: GradeA (43).jpg
# ✅ Copied GradeA (52).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (127).jpg
# 🔁 Skipped duplicate: 8C_A (24).jpg
# 🔁 Skipped duplicate: 8C_A (23).jpg
# 🔁 Skipped duplicate: GradeA (49).jpg
# 🔁 Skipped duplicate: GradeA (138).jpg
# 🔁 Skipped duplicate: GradeA (64).jpg
# 🔁 Skipped duplicate: GradeA (59).jpg
# 🔁 Skipped duplicate: 8C_A (3).jpg
# 🔁 Skipped duplicate: GradeA (2).jpg
# 🔁 Skipped duplicate: GradeA (112).jpg
# 🔁 Skipped duplicate: GradeA (115).jpg
# 🔁 Skipped duplicate: GradeA (99).jpg
# 🔁 Skipped duplicate: GradeA (20).jpg
# 🔁 Skipped duplicate: GradeA (77).jpg
# 🔁 Skipped duplicate: GradeA (86).jpg
# ✅ Copied GradeA (102).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (10).jpg
# 🔁 Skipped duplicate: 8C_A (26).jpg
# 🔁 Skipped duplicate: GradeA (28).jpg
# 🔁 Skipped duplicate: 8C_A (22).jpg
# ✅ Copied GradeA (136).jpg → 8cell_grade_A
# ✅ Copied GradeA (11).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (17).jpg
# 🔁 Skipped duplicate: 8C_A (39).jpg
# ✅ Copied GradeA (122).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (40).jpg
# 🔁 Skipped duplicate: GradeA (101).jpg
# ✅ Copied GradeA (113).jpg → 8cell_grade_A
# ✅ Copied GradeA (76).jpg → 8cell_grade_A
# ✅ Copied GradeA (63).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (87).jpg
# 🔁 Skipped duplicate: GradeA (36).jpg
# 🔁 Skipped duplicate: 8C_A (7).jpg
# 🔁 Skipped duplicate: GradeA (57).jpg
# 🔁 Skipped duplicate: GradeA (92).jpg
# 🔁 Skipped duplicate: GradeA (24).jpg
# 🔁 Skipped duplicate: GradeA (62).jpg
# 🔁 Skipped duplicate: 8C_A (21).jpg
# 🔁 Skipped duplicate: 8C_A (35).jpg
# 🔁 Skipped duplicate: 8C_A (5).jpg
# ✅ Copied GradeA (125).jpg → 8cell_grade_A
# ✅ Copied GradeA (50).jpg → 8cell_grade_A
# ✅ Copied GradeA (114).jpg → 8cell_grade_A
# ✅ Copied GradeA (60).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (25).jpg
# 🔁 Skipped duplicate: GradeA (23).jpg
# ✅ Copied GradeA (41).jpg → 8cell_grade_A
# ✅ Copied GradeA (27).jpg → 8cell_grade_A
# ✅ Copied GradeA (90).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_a (29).jpg
# 🔁 Skipped duplicate: 8C_a (31).jpg
# 🔁 Skipped duplicate: 8C_A (13).jpg
# 🔁 Skipped duplicate: GradeA (30).jpg
# ✅ Copied GradeA (18).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (14).jpg
# 🔁 Skipped duplicate: GradeA (116).jpg
# 🔁 Skipped duplicate: 8c_a (33).jpg
# 🔁 Skipped duplicate: GradeA (38).jpg
# ✅ Copied GradeA (74).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_a (32).jpg
# 🔁 Skipped duplicate: GradeA (134).jpg
# ✅ Copied GradeA (5).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (10).jpg
# 🔁 Skipped duplicate: 8C_A (40).jpg
# ✅ Copied GradeA (126).jpg → 8cell_grade_A
# ✅ Copied GradeA (22).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (4).jpg
# 🔁 Skipped duplicate: 8C_A (11).jpg
# 🔁 Skipped duplicate: GradeA (33).jpg
# ✅ Copied GradeA (35).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (104).jpg
# ✅ Copied GradeA (3).jpg → 8cell_grade_A
# ✅ Copied GradeA (26).jpg → 8cell_grade_A
# ✅ Copied GradeA (110).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (14).jpg
# ✅ Copied GradeA (16).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (19).jpg
# 🔁 Skipped duplicate: 8C_A (34).jpg
# 🔁 Skipped duplicate: GradeA (46).jpg
# ✅ Copied GradeA (45).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_a (38).jpg
# ✅ Copied GradeA (15).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (9).jpg
# ✅ Copied GradeA (29).jpg → 8cell_grade_A
# ✅ Copied GradeA (37).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (17).jpg
# 🔁 Skipped duplicate: 8C_a (28).jpg
# 🔁 Skipped duplicate: GradeA (6).jpg
# 🔁 Skipped duplicate: 8C_A (41).jpg
# ✅ Copied GradeA (135).jpg → 8cell_grade_A
# ✅ Copied GradeA (55).jpg → 8cell_grade_A
# ✅ Copied GradeA (44).jpg → 8cell_grade_A
# ✅ Copied GradeA (139).jpg → 8cell_grade_A
# ✅ Copied GradeA (56).jpg → 8cell_grade_A
# ✅ Copied GradeA (88).jpg → 8cell_grade_A
# ✅ Copied GradeA (100).jpg → 8cell_grade_A
# ✅ Copied GradeA (34).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (6).jpg
# 🔁 Skipped duplicate: 8C_A (20).jpg
# ✅ Copied GradeA (61).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A (18).jpg
# 🔁 Skipped duplicate: 8C_A (15).jpg
# ✅ Copied GradeA (8).jpg → 8cell_grade_A
# ✅ Copied GradeA (58).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: 8C_A.jpg
# ✅ Copied GradeA (53).jpg → 8cell_grade_A
# ✅ Copied GradeA (12).jpg → 8cell_grade_A
# ✅ Copied GradeA (47).jpg → 8cell_grade_A
# ✅ Copied GradeA (31).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (80).jpg
# ✅ Copied GradeA (39).jpg → 8cell_grade_A
# ✅ Copied GradeA (7).jpg → 8cell_grade_A
# ✅ Copied GradeA (67).jpg → 8cell_grade_A
# ✅ Copied GradeA (91).jpg → 8cell_grade_A
# 🔁 Skipped duplicate: GradeA (128).jpg
# ✅ Copied GradeA (21).jpg → 8cell_grade_A
#
# ==================================================
# Data labeling complete!
# ==================================================
#
# Files per category:
#   - morula_grade_C: 150 files
#   - morula_grade_B: 150 files
#   - morula_grade_A: 134 files
#   - blastocyst_grade_C: 150 files
#   - error_images: 500 files
#   - blastocyst_grade_A: 149 files
#   - 8cell_grade_A: 150 files
#   - blastocyst_grade_B: 152 files
#   - 8cell_grade_C: 150 files
#   - 8cell_grade_B: 150 files
#
# Total files processed: 1835
#
# ✅ label completed successfully in 0.33 seconds
#
# ================================================================================
# =========================== Running check_image_size ===========================
# ================================================================================
#
# ✅ check_image_size completed successfully in 0.00 seconds
#
# ================================================================================
# ============================ Running CleanAndVerify ============================
# ================================================================================
#
# ✅ CleanAndVerify completed successfully in 0.00 seconds
#
# ================================================================================
# ================================ Running imgaug ================================
# ================================================================================
#
# ✅ imgaug completed successfully in 0.00 seconds
#
# ================================================================================
# ============================== Running normalize ===============================
# ================================================================================
# 🔍 Starting image normalization process
#    - Normalization type: simple
#    - Target size: (224, 224)
#
# 🔄 Processing images from /content/EmbryoQualityPrediction/embryo-quality-prediction/data/sorted
# Normalizing morula_grade_C: 100% 150/150 [00:00<00:00, 169261.66it/s]
# Normalizing morula_grade_B: 100% 150/150 [00:00<00:00, 174714.13it/s]
# Normalizing morula_grade_A: 100% 134/134 [00:00<00:00, 166283.06it/s]
# Normalizing blastocyst_grade_C: 100% 150/150 [00:00<00:00, 9874.22it/s]
# Normalizing error_images: 100% 500/500 [00:00<00:00, 18782.76it/s]
# Normalizing blastocyst_grade_A: 100% 149/149 [00:00<00:00, 2745.76it/s]
# Normalizing 8cell_grade_A: 100% 150/150 [00:00<00:00, 978.51it/s]
# Normalizing blastocyst_grade_B: 100% 152/152 [00:00<00:00, 2522.70it/s]
# Normalizing 8cell_grade_C: 100% 150/150 [00:00<00:00, 1059.45it/s]
# Normalizing 8cell_grade_B: 100% 150/150 [00:00<00:00, 834.53it/s]
#
# 🔄 Processing images from /content/EmbryoQualityPrediction/embryo-quality-prediction/data/augmented
# Normalizing morula_grade_C: 100% 1050/1050 [00:00<00:00, 148729.16it/s]
# Normalizing morula_grade_B: 100% 1050/1050 [00:00<00:00, 149929.16it/s]
# Normalizing morula_grade_A: 100% 1072/1072 [00:00<00:00, 146597.56it/s]
# Normalizing blastocyst_grade_C: 100% 1000/1000 [00:00<00:00, 170002.59it/s]
# Normalizing error_images: 100% 1000/1000 [00:00<00:00, 185720.16it/s]
# Normalizing blastocyst_grade_A: 100% 1000/1000 [00:00<00:00, 179743.05it/s]
# Normalizing 8cell_grade_A: 100% 1089/1089 [00:00<00:00, 184155.02it/s]
# Normalizing blastocyst_grade_B: 100% 1050/1050 [00:00<00:00, 182557.59it/s]
# Normalizing 8cell_grade_C: 100% 1030/1030 [00:00<00:00, 181403.87it/s]
# Normalizing 8cell_grade_B: 100% 1080/1080 [00:00<00:00, 184816.33it/s]
#    - morula_grade_C: 1050 images
#    - morula_grade_B: 1050 images
#    - morula_grade_A: 1072 images
#    - blastocyst_grade_C: 1004 images
#    - error_images: 1003 images
#    - blastocyst_grade_A: 1019 images
#    - 8cell_grade_A: 1140 images
#    - blastocyst_grade_B: 1063 images
#    - 8cell_grade_C: 1077 images
#    - 8cell_grade_B: 1140 images
#
# ✅ Normalization complete: 10618 images normalized using simple normalization
#    - Files processed: 197
#    - Files skipped (already normalized): 12057
#
# ✅ normalize completed successfully in 0.72 seconds
#
# ================================================================================
# ============================ Running split_dataset =============================
# ================================================================================
# 🔍 Starting dataset splitting process...
#
# ✅ Split directories already contain data. Skipping split process.
#    - Train directory: /content/EmbryoQualityPrediction/embryo-quality-prediction/data/split/train
#    - Validation directory: /content/EmbryoQualityPrediction/embryo-quality-prediction/data/split/val
#    - Test directory: /content/EmbryoQualityPrediction/embryo-quality-prediction/data/split/test
#
# ✅ split_dataset completed successfully in 0.00 seconds
#
# ================================================================================
# ========================== PHASE 2: MODEL DEVELOPMENT ==========================
# ================================================================================
#
# ================================================================================
# =============================== MODEL SELECTION ================================
# ================================================================================
# Select a model architecture for training:
# 1. ResNet152 (default)
# 2. DenseNet201
# 3. EfficientNet-B7
# 4. ConvNeXt Base
# 5. SwinV2
# 6. EfficientViT
#
# Select which model to use (enter the number or press Enter for default):
# Workflow interrupted by user.Traceback (most recent call last):
#   File "/content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py", line 581, in <module>
#     main()
#   File "/content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py", line 491, in main
#     select_model()
#   File "/content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py", line 295, in select_model
#     selection = input("\nSelect which model to use (enter the number or press Enter for default): ")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py", line 583, in <module>
#     print("\nWorkflow interrupted by user.")
# KeyboardInterrupt
# ^C

# %%
# Step 1: Zip both folders
# !zip -r /content/models.zip /content/EmbryoQualityPrediction/embryo-quality-prediction/models
# !zip -r /content/outputs.zip /content/EmbryoQualityPrediction/embryo-quality-prediction/outputs

# Step 2: Download them
from google.colab import files
files.download('/content/models.zip')
files.download('/content/outputs.zip')
files.download('/content/EmbryoQualityPrediction/embryo-quality-prediction/model_report.html')
# Out:
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/models/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/models/swinv2_20250426_122910.pth (deflated 64%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/models/swinv2_final.pth (deflated 64%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/plots/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/plots/confusion_matrix.png (deflated 16%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/plots/swinv2_training_plot_20250426_122911.png (deflated 8%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120325/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120325/plots/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120325/plots/class_distribution.png (deflated 21%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120325/swinv2_report.html (deflated 71%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_results.csv (deflated 67%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_122912/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_122912/plots/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_122912/plots/confusion_matrix.png (deflated 16%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_122912/swinv2_report.html (deflated 80%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120330/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120330/plots/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120330/plots/training_loss.png (deflated 10%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120330/plots/training_accuracy.png (deflated 9%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_120330/swinv2_report.html (deflated 73%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_122916/ (stored 0%)
#   adding: content/EmbryoQualityPrediction/embryo-quality-prediction/outputs/results/swinv2_20250426_122916/swinv2_final.pth (deflated 64%)

# %%
# !cp /content/EmbryoQualityPrediction/embryo-quality-prediction/models/zip/my_folder.zip /content/drive/MyDrive/Models/

# %%
# !pip install -r /content/EmbryoQualityPrediction/embryo-quality-prediction/requirements.txt

# %%
# !python /content/EmbryoQualityPrediction/embryo-quality-prediction/run_workflow.py
