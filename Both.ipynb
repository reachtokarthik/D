# %% [markdown]
# <a href="https://colab.research.google.com/github/reachtokarthik/EmbryoQualityPrediction/blob/main/Both.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf D  # remove the current D folder if it’s not a real repo
# !git clone https://github.com/reachtokarthik/D.git
# !cd D && git log -1
# Out:
# Cloning into 'D'...
# remote: Enumerating objects: 52346, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 52346 (delta 0), reused 1 (delta 0), pack-reused 52337 (from 1)
# Receiving objects: 100% (52346/52346), 965.79 MiB | 41.41 MiB/s, done.
# Resolving deltas: 100% (164/164), done.
# Updating files: 100% (25044/25044), done.
# commit 8aa86b9a091808f704317ee830c15fb58a46d79a (HEAD -> main, origin/main, origin/HEAD)
# Author: reachtokarthik <reachtokarthikeyan@outlook.com>
# Date:   Thu Apr 24 07:19:07 2025 +0530
#
#     Add workflow modes and support for multiple datasets with model selection

# %%
# !python /content/D/embryo-quality-prediction/run_workflow.py
# Out:
# ...
# ======================== EMBRYO CLASSIFICATION WORKFLOW ========================
# ...
# Starting workflow at: 2025-04-24 01:51:13
# Project root: /content/D/embryo-quality-prediction
#
# ...
# =========================== WORKFLOW MODE SELECTION ============================
# ...
# Select workflow mode:
# 1. Automatic mode (use default values for all selections)
# 2. Interactive mode (prompt for each selection)
# 3. Step-by-Step mode (run each workflow step individually)
#
# Select mode (1-3) or press Enter for interactive mode: 1
# Selected: Automatic mode
#
# Automatic mode selected: Both dataset
#
# ...
# =============================== WORKFLOW PHASES ================================
# ...
#
# ...
# ================================ Running label =================================
# ...
# 📁 Created target folder: morula_grade_A
# 📁 Created target folder: morula_grade_C
# 📁 Created target folder: blastocyst_grade_B
# 📁 Created target folder: error_images
# 📁 Created target folder: 8cell_grade_C
# ...

# %%
# !pip install -r /content/D/embryo-quality-prediction/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.1/604.1 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 98.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 38.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 8.3 MB/s eta 0:00:00
# ...
